# %%
import matplotlib.pyplot as plt # type: ignore
import pandas as pd # type: ignore
import numpy as np

# %% [markdown]
# #### Matplotlib Testing

# %%
x = np.array([1, 4, -5, 9])
y = np.array([2, 5, 6, 3])

plt.plot(x, y)

# %% [markdown]
# #### Pandas Testing

# %%
print('Data Frame')
my_data = {
    'name' : ['tuan', 'phuong'],
    'age' : [18, 18],
    'handsomeness' : [10, 15]
}

data = pd.DataFrame(my_data)
print(data, '\n')
print(data.loc[[0, 1]])
print(data.loc[0])

print('\n\n\n')

print('Series')
second_data = ['lmao', 'lol', 'XD', 'crazy']
second_data = pd.Series(second_data, index = ["a", "b", "c", "d"])
print(second_data)
print(second_data[[3, 2]])
print(second_data["a"])

print('\n\n\n')
# Out:
# Data Frame
#      name  age  handsomeness
# 0    tuan   18            10
# 1  phuong   18            15
#
#      name  age  handsomeness
# 0    tuan   18            10
# 1  phuong   18            15
# name            tuan
# age               18
# handsomeness      10
# Name: 0, dtype: object
#
#
#
#
# Series
# a     lmao
# b      lol
# c       XD
# d    crazy
# dtype: object
# d    crazy
# c       XD
# dtype: object
# lmao
# C:\Users\admin\AppData\Local\Temp\ipykernel_3728\1644082251.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(second_data[[3, 2]])

# %%
df = pd.read_csv('data.csv')
# print(df.to_string()) print the whole csv file
# pd.options.display.max_rows = 200
print(df)

# testing if i can plot the graph
x = df['Duration']
y = df['Pulse']
plt.subplot(3, 3, 1)
plt.bar(x, y)

plt.subplot(3, 3, 2)
plt.barh(x, y)

plt.subplot(3, 3, 3)
plt.plot(x) # x-axis will be the index (0, 1, 2,...)

plt.subplot(3, 3, 4)
plt.plot(df.loc[0]) # x-axis will be the index ('Duration', 'Pulse',...)

plt.subplot(3, 3, 5)
plt.plot(df.loc[0], df.loc[1]) # x-axis will be values of row 0, y-axis will be values of row 1
plt.plot(df['Duration'], df['Pulse']) # x-axis will be values of column 'Duration', y-axis will be values of column 'Pulse'

plt.subplot(3, 3, 6)
plt.plot(df[0:4]) # for ex df[0] -> series -> then the x-axis will be the index (0, 1, 2, 3, 4), y-axis will be the values of column 0

plt.subplot(3, 3, 7)
plt.plot(df[0:4], df[0:4], 'o') # i guess there will be 4 straigt lines

plt.subplot(3, 3, 8)
plt.plot(df.loc[0:50], df.loc[51:101]) # x-axis will be the values of row 0, 1, 2, y-axis will be the values of row 3, 4

plt.subplot(3, 3, 9)
# y-axis = 10
plt.plot(df.loc[0: 4], 5 * [10]) # y-axis = 10

print(df.loc[0][0])
print(df.loc[[0, 1]].loc[0]['Pulse'])
print(df.loc[0:4]) # -> it prints the first 5 series. and it is the same as df.loc[[0, 1, 2, 3, 4]] which returns a dataframe. But both methods are different, first oen is slicing, second is... i don't know
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
# C:\Users\admin\AppData\Local\Temp\ipykernel_3728\3750901977.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df.loc[0][0])
# 60.0
# 110.0
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# ...

# %%
df = pd.read_json('data.js')
print(df, '\n')
print(df.head(10), '\n')
print(df.tail(), '\n')
print(df.info(), '\n')
print(df.describe(), '\n')
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
#
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.5
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0
#
# ...

# %%
df = pd.read_json('data1.js')
print(df.head(27), '\n')
print(df.info(), '\n\n\n')

new_df = df.dropna()
# df.dropna(inplace = True) == df = df.dropna()
print(new_df.info(), '\n\n\n')

mean_val = df.mean()
new_df = df.fillna(mean_val)
print(new_df.info(), '\n\n\n')

mod = df['Duration'].mode()[0]
mod2 = df['Calories'].median()
new_df = df['Duration'].fillna(mod)
new_df2 = df['Date'].fillna(mod2)
print(new_df.info(), '\n\n\n')

# mean, median, mode (.mode()[0] -> value appears most frequently)


# df['Date'] = pd.to_datetime(df['Date']) # if there is any column with wrong format. For example: 20200626
# it even converts NaN to NaT, then:
# df.dropna(subset = ['Date'], inplace = True)
# df.drop('Date', axis = 1, inplace = True) 1 la column, 0 la row
# df.drop(0, inplace = True)
# df['Calories'].dropna(inplace = True)
# CANT RUN: df.loc[0].dropna(inplace = True)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
df = pd.read_json('data1.js')
print(df.head(10), '\n')
# Done use: df['Duration'][7] = 45. Use this instead: (kieu giong nhu: hang - cot chu ko phai cot - hang)
df.loc[7, 'Duration'] = 45
print(df.head(10), '\n')

for x in df.index:
    if df.loc[x, 'Duration'] > 100:
        df.loc[x, 'Duration'] = 50

for x in df.columns:
    if 'i am handsome' == df.loc[5, x]:
        print('Yes')

for x in df.index:
    if df.loc[x, 'Duration'] > 120:
        df.drop(x, inplace = True)
        
print(df.head(10))
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories
# 0        60 2020-12-01    110       130     409.1
# 1        60 2020-12-02    117       145     479.0
# 2        60 2020-12-03    103       135     340.0
# 3        45 2020-12-04    109       175     282.4
# 4        45 2020-12-05    117       148     406.0
# 5        60 2020-12-06    102       127     300.0
# 6        60 2020-12-07    110       136     374.0
# 7       450 2020-12-08    104       134     253.3
# 8        30 2020-12-09    109       133     195.1
# 9        60 2020-12-10     98       124     269.0
#
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# ...

# %%
df = pd.read_json('data1.js')
print(df.head(15))
print(df.duplicated().head(15))
df.drop_duplicates(inplace = True)
print(df.head(15))
# Can't run. Because it faces the same problem as when u practiced CS50 remember? if u are deleting while looping -> error -> must use .copy() or deepcopy()
# for i in range(15):
#     index = df.loc[i]
#     if index['Duration'] > 100:
#         df.drop(i, inplace = True)
# instead:
for index in df.index:
    if df.loc[index, 'Duration'] > 100:
        df.drop(index, inplace = True)
# or df = df[df['Duration'] <= 100]
print(df.head(15))
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# ...

# %%
df = pd.read_csv('data.csv')
print(df.head(), '\n')
print(df.corr())

print('\n\n')
#df.plot(kind = 'scatter', x = 'Duration', y = 'Calories') # the same as plt.plot(df['Duration], df['Calories'], 'o')
# df['Duration'].plot(kind = 'hist')

# x = range(0, 300)
# y = range(0, 300)
plt.plot(df['Duration'], color = 'red', label = 'Duration')
plt.plot(df['Pulse'], color = 'blue', label = 'Pulse')
plt.plot(df['Calories'], color = 'green', label = 'Calories')
plt.plot(df['Maxpulse'], color = 'yellow', label = 'Maxpulse')
plt.legend()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('You')
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
#
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000
# Text(0.5, 1.0, 'You')
